# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %% [markdown]
# # Sample Extraction Process

# %%
url="https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/"
source=requests.get(url).text
soup=BeautifulSoup(source,'lxml')

# %%
article=soup.find('article')
headline=article.h1.text
print(headline)

# %%
summary=article.find('div',class_="td-post-content").text

# %%
csv_file=open('37.csv','w')
csv_writer=csv.writer(csv_file)
csv_writer.writerow(['headline','summary'])
csv_writer.writerow([headline,summary])
csv_file.close()

# %% [markdown]
# # Importing Input data

# %%
input=pd.read_csv(r"C:\Users\vasan\Downloads\Input.xlsx - Sheet1.csv")
input
# Out:
#      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]

# %% [markdown]
# # Creating a loop to automatically fetch and save the data in csv file

# %%
for i in input.values:
    url=i[1]
    source=requests.get(url)
    if (source.status_code==200):
        print('DataFetched',i[0])
        soup=BeautifulSoup(source.text,'lxml')
        article=soup.find('article')
        for article in soup.find_all('article'):
            headline=article.h1.text
            summary=article.find('div',class_="td-post-content").text
            summary=summary.replace('\n',' ')
            csv_file=open(f'{i[0]}.csv','w',encoding='utf-8')
            csv_writer=csv.writer(csv_file)
            csv_writer.writerow(['headline','summary'])
            csv_writer.writerow([headline,summary])
            csv_file.close()
    else:
        print('Not Working',i[0])
# Out:
# DataFetched 37
# DataFetched 38
# DataFetched 39
# DataFetched 40
# DataFetched 41
# DataFetched 42
# DataFetched 43
# Not Working 44
# DataFetched 45
# DataFetched 46
# DataFetched 47
# DataFetched 48
# DataFetched 49
# DataFetched 50
# DataFetched 51
# DataFetched 52
# DataFetched 53
# DataFetched 54
# DataFetched 55
# DataFetched 56
# Not Working 57
# DataFetched 58
# DataFetched 59
# DataFetched 60
# DataFetched 61
# DataFetched 62
# DataFetched 63
# DataFetched 64
# DataFetched 65
# DataFetched 66
# DataFetched 67
# DataFetched 68
# DataFetched 69
# DataFetched 70
# DataFetched 71
# DataFetched 72
# DataFetched 73
# DataFetched 74
# DataFetched 75
# DataFetched 76
# DataFetched 77
# DataFetched 78
# DataFetched 79
# DataFetched 80
# DataFetched 81
# DataFetched 82
# DataFetched 83
# DataFetched 84
# DataFetched 85
# DataFetched 86
# DataFetched 87
# DataFetched 88
# DataFetched 89
# DataFetched 90
# DataFetched 91
# DataFetched 92
# DataFetched 93
# DataFetched 94
# ...

# %% [markdown]
# # This Three webpage has connection error - 404 not found

# %%
a=input['URL'][input['URL_ID']==44]
b=input['URL'][input['URL_ID']==57]
c=input['URL'][input['URL_ID']==122]
b
